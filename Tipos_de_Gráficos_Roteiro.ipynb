# %% [markdown]
# <a href="https://colab.research.google.com/github/Laura-Parhuts/Analise-de-dados-e-mineracao/blob/main/Tipos_de_Gr%C3%A1ficos_Roteiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Roteiro para Criação de Gráficos

# %%
# !pip install -U --no-cache-dir gdown --pre

# %%
import gdown
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !gdown 1GZkHDnV3fMCSFvvKSyPP14AFMdEfqacx
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GZkHDnV3fMCSFvvKSyPP14AFMdEfqacx
# To: /content/vendas_produtos.csv
# 100% 227/227 [00:00<00:00, 1.05MB/s]

# %%
df = pd.read_csv('vendas_produtos.csv')
df
# Out:
#    Meses  Produto 1  Produto 2  Produto 3
# 0    Jan        120        100         90
# 1    Fev        150        130        110
# 2    Mar        170        165        140
# 3    Abr        200        195        180
# 4    Mai        165        175        170
# 5    Jun        180        180        175
# 6    Jul        220        215        205
# 7    Ago        230        225        210
# 8    Set        210        210        200
# 9    Out        210        200        190
# 10   Nov        240        230        215
# 11   Dez        260        250        230

# %%
#estilo de cor
plt.style.use('ggplot') 

# Aumentar o tamanho da fonte
plt.rcParams.update({'font.size': 16})

# Criar um gráfico de linha
plt.figure(figsize=(16, 12))

#descompactar lista
produto1, = plt.plot(df['Meses'], df['Produto 1'], label='Produto 1', marker='o') 
produto2, = plt.plot(df['Meses'], df['Produto 2'], label='Produto 2', marker='o')
produto3, = plt.plot(df['Meses'], df['Produto 3'], label='Produto 3', marker='o')


plt.legend([produto1, produto2, produto3], ['Produto 1', 'Produto 2', 'Produto 3'])
plt.title('Vendas de Produtos (2023)')
plt.xlabel('Mês')
plt.ylabel('Vendas')

plt.savefig('GraficoLinha.svg')
# Mostrar o gráfico
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# # Mude o estilo do gráfico de linhas por seu estilo favorito:

# %%
df
# Out:
#    Meses  Produto 1  Produto 2  Produto 3
# 0    Jan        120        100         90
# 1    Fev        150        130        110
# 2    Mar        170        165        140
# 3    Abr        200        195        180
# 4    Mai        165        175        170
# 5    Jun        180        180        175
# 6    Jul        220        215        205
# 7    Ago        230        225        210
# 8    Set        210        210        200
# 9    Out        210        200        190
# 10   Nov        240        230        215
# 11   Dez        260        250        230

# %%
#estilo de cor
plt.style.use('fivethirtyeight') 

# Aumentar o tamanho da fonte
plt.rcParams.update({'font.size': 16})

# Criar um gráfico de linha
plt.figure(figsize=(10, 10))

#descompactar lista
produto1, = plt.plot(df['Meses'], df['Produto 1'], label='Produto 1', marker='o') 
produto2, = plt.plot(df['Meses'], df['Produto 2'], label='Produto 2', marker='o')
produto3, = plt.plot(df['Meses'], df['Produto 3'], label='Produto 3', marker='o')


plt.legend([produto1, produto2, produto3], ['Produto 1', 'Produto 2', 'Produto 3'])
plt.title('Vendas de Produtos (2023)')
plt.xlabel('Mês')
plt.ylabel('Vendas')

plt.savefig('GraficoLinha.svg')
# Mostrar o gráfico
plt.show()

# %% [markdown]
# #Crie uma função para realizar o gráfico de linhas passando como parâmetro o estilo
#
# # def GraficoLinha(style)

# %%
def GraficoLinha(style='ggplot'):
  #estilo de cor
  plt.style.use(style) 

  # Aumentar o tamanho da fonte
  plt.rcParams.update({'font.size': 16})

  # Criar um gráfico de linha
  plt.figure(figsize=(16, 12))

  #descompactar lista
  produto1, = plt.plot(df['Meses'], df['Produto 1'], label='Produto 1', marker='o') 
  produto2, = plt.plot(df['Meses'], df['Produto 2'], label='Produto 2', marker='o')
  produto3, = plt.plot(df['Meses'], df['Produto 3'], label='Produto 3', marker='o')


  plt.legend([produto1, produto2, produto3], ['Produto 1', 'Produto 2', 'Produto 3'])
  plt.title('Vendas de Produtos (2023)')
  plt.xlabel('Mês')
  plt.ylabel('Vendas')

  plt.savefig('GraficoLinha.svg')
  # Mostrar o gráfico

  plt.show()

# %%
GraficoLinha('Solarize_Light2')

# %% [markdown]
# # Agora faça o mesmo para o gráfico de barras

# %%
# !gdown 1GfjQWcme9Jbs3yCns6o_UzxKhg6cGleV
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GfjQWcme9Jbs3yCns6o_UzxKhg6cGleV
# To: /content/Produtos_cat_vend.csv
# 100% 86.0/86.0 [00:00<00:00, 370kB/s]

# %%
df = pd.read_csv('Produtos_cat_vend.csv')
df
# Out:
#     Produtos  Vendas
# 0  Produto 1     123
# 1  Produto 2     432
# 2  Produto 3     331
# 3  Produto 4     456
# 4  Produto 5     231

# %%
# Criar o gráfico de barras
#plt.bar(df['Produtos'], df['Vendas'])
#Barra Horizontal
plt.barh(df['Produtos'], df['Vendas'])


plt.title('Vendas de Produtos')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')

# Mostrar o gráfico
plt.show()

# %%
def GraficoBarra(style='barh'):
  plt.style.use(style) 

plt.barh(df['Produtos'], df['Vendas'])


plt.title('Vendas de Produtos')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# # Gráfico de Dispersão
# ## Crie uma função

# %%
# !gdown 1GijLvrGSDA5GHVZw8TlZ3cDZXRIjCw2j
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GijLvrGSDA5GHVZw8TlZ3cDZXRIjCw2j
# To: /content/Idade_Carro.csv
# 100% 97.0/97.0 [00:00<00:00, 582kB/s]

# %%
df = pd.read_csv('Idade_Carro.csv')
df
# Out:
#     Idade  Preço
# 0       5   9500
# 1       7   7000
# 2       8   6300
# 3      10   5500
# 4      12   4800
# 5      15   3900
# 6      20   2800
# 7      22   2200
# 8      24   1800
# 9      26   1500
# 10     30    800

# %%
# Criar o gráfico de dispersão
plt.scatter(df['Idade'], df['Preço'])

plt.title('Preço do Carro x Idade')
plt.xlabel('Idade do Carro (Anos)')
plt.ylabel('Preço (R$)')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# # Explique como esse gráfico:

# %% [markdown]
# # Por que é interessante fazer um gráfico de dispersão nesse caso?
# R: Pois traz os valores mais perto da linha, já os preços que estiverem muito disperos, ficarão mais longe das linhas.

# %% [markdown]
# # Qual é a diferença entre o gráfico de linha na interpretação?
# R: O gráfico de linha serve para análises temporais, porém não mostra de forma uniforme a dispersão

# %% [markdown]
# # Historiograma

# %% [markdown]
# ## Modifique a distribuição aleatória para distribuição normal - Pesquise a função numpy

# %%
# Vamos gerar um conjunto de dados aleatórios para as idades
np.random.seed(0)
idades = np.random.randint(0, 100, size=1000) #distribuição aleatória de valor inteiro

# Criar o histograma
plt.hist(idades, bins=20, edgecolor='black')

plt.title('Distribuição das Idades')
plt.xlabel('Idade')
plt.ylabel('Frequência')

# Mostrar o gráfico
plt.show()

# %%
pos = 100
scale = 5
size = 100000
idades = np.random.normal(pos, scale, size) 
plt.hist(idades, 100) 
plt.show()

# %% [markdown]
# # Interprete a distribuição distribuição e compare a diferença com a distribuição normal
#
# R: A média é 100 das idades em uma escala até 3.500

# %% [markdown]
# # Gráfico de Donut

# %%
# Dados
generos = ['Feminino', 'Masculino']
quantidade = [650, 550]

# %%
# Criar o gráfico de pizza
plt.pie(quantidade, labels=generos, autopct='%1.1f%%', startangle=90, colors=['#FFC0CB', '#0000FF'], wedgeprops={'width': 0.4})

plt.title('Distribuição de Gênero')


# Mostrar o gráfico
plt.show()

# %% [markdown]
# # DESAFIO
#
# Deixe o gráfico dessa maneira:
#
# ![image.png](data:image/png;base64,...)

# %%
# Criar o gráfico de pizza

plt.style.use('classic')
plt.style.use('bmh')
quantidade=[21, 18]
ax = plt.axes() 
plt.title('Distribuição de Gênero')

plt.pie(quantidade, labels=generos, autopct='%1.1f%%', startangle=90, colors=['#FFC0CB', '#0000FF'], wedgeprops={'width': 0.4})

#não consegui terminar

# Mostrar o gráfico
plt.show()

# %% [markdown]
# # Gráfico de Caixa (Box Plot)

# %%
# Dados
distribuicao = np.random.normal(40, 20, 120)

# Criar o gráfico de caixa
plt.boxplot(distribuicao)

plt.title('Distribuição Personalizada')
plt.xlabel('Dados')
plt.ylabel('Valores')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# # Explique o Gráfico acima -- Pesquise
# R: A média ficou entre 25 a 55, sendo que a distribuição normalizada ocorre entre -20 até no máximo 90

# %% [markdown]
# # Diagrama de Violino

# %%
# !gdown 1GvcLp9qKfSI2o0CHvXjsGXDRTZ91SGy9
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GvcLp9qKfSI2o0CHvXjsGXDRTZ91SGy9
# To: /content/Pontuacao.csv
# 100% 7.21k/7.21k [00:00<00:00, 31.1MB/s]

# %%
df = pd.read_csv('Pontuacao.csv')
df
# Out:
#      Equipe A   Equipe B   Equipe C    Equipe D
# 0   77.167926  66.463595  84.559014  106.970881
# 1   76.764764  74.350674  60.319876   87.518938
# 2   78.553779  67.191898  75.061567   98.556478
# 3   95.368871  74.888618  85.402054   86.279746
# 4   77.728494  70.933726  66.396115   76.258294
# ..        ...        ...        ...         ...
# 95  90.423557  78.783529  92.011516   83.443977
# 96  84.609794  74.999238  90.105536   87.627799
# 97  76.816536  76.896912  85.177010   83.862049
# 98  76.153257  80.493461  90.174774   91.256109
# 99  78.244719  71.860788  96.877019   80.089023
#
# [100 rows x 4 columns]

# %%
# Criar o gráfico de violino
equipes = df.columns.tolist()
plt.figure(figsize=(8, 6))
plt.violinplot(df)

# Personalizar o gráfico
plt.title('Distribuição da Pontuação por Equipe')
plt.xlabel('Equipes')
plt.ylabel('Pontuação')

plt.xticks(np.arange(1, len(equipes)+1), equipes)

# Mostrar o gráfico
plt.show()

# %% [markdown]
# # Explique o gráfico acima, qual é a diferença da Equipe C da Equipe D.
# R:

# %%
#A equipe C pontuou entre 55 a 125 pontos. A equipe D concentrou seus pontos de 70 a 110.
